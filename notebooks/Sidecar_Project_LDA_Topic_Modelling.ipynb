# %% [markdown]
# <a href="https://colab.research.google.com/github/mmonch/Sidecar_Project/blob/main/notebooks/Sidecar_Project_LDA_Topic_Modelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a id='Q0'></a>
# <center><a target="_blank" href="https://sit.academy/"><img src="https://drive.google.com/uc?id=1z0U84GYqhbWWpCenFajh8_8XFRGyOc3U" width="200" style="background:none; border:none; box-shadow:none;" /></a> </center>
# <center> <h1> Notebook #: Title of Notebook </h1> </center>
# <p style="margin-bottom:1cm;"></p>
# <center><h4>SIT Academy, 2022</h4></center>
# <p style="margin-bottom:1cm;"></p>
#
# <div style="background:#EEEDF5;border-top:0.1cm solid #EF475B;border-bottom:0.1cm solid #EF475B;">
#     <div style="margin-left: 0.5cm;margin-top: 0.5cm;margin-bottom: 0.5cm;color:#303030">
#         <p><strong>Goal:</strong> Short description of the aim of the notebook</p>
#         <strong> Outline:</strong>
#         <a id='P0' name="P0"></a>
#         <ol>
#             <li> <a style="color:#303030" href='#I'>Introduction </a> </li>
#             <li> <a style="color:#303030" href='#SU'>Set up</a></li>
#             <li> <a style="color:#303030" href='#P1'>Attribute Business Name Topic Modelling</a></li>
#             <li> <a style="color:#303030" href='#P2'>Attribute Business Description Topic Modelling</a></li>
#             <li> <a style="color:#303030" href='#P3'>Part 3</a></li>
#             <li> <a style="color:#303030" href='#CL'>Conclusion</a></li>
#         </ol>
#         <strong>Keywords:</strong> data cleaning, NLP, ... list of keywords.
#     </div>
# </div>
# </nav>

# %% [markdown]
# <a id='I' name="I"></a>
# ## [Introduction](#P0)

# %% [markdown]
# Source: https://towardsdatascience.com/topic-modeling-on-pycaret-2ce0c65ba3ff
#
# PyCarets offers a variety of plots. The type of graph generated will depend on the plot parameter. Here is the list of currently available visualizations:
# - ‘frequency’: Word Token Frequency (default)
# - ‘distribution’: Word Distribution Plot
# - ‘bigram’: Bigram Frequency Plot
# - ‘trigram’: Trigram Frequency Plot
# - ‘sentiment’: Sentiment Polarity Plot
# - ‘pos’: Part of Speech Frequency
# - ‘tsne’: t-SNE (3d) Dimension Plot
# - ‘topic_model’ : Topic Model (pyLDAvis)
# - ‘topic_distribution’ : Topic Infer Distribution
# - ‘wordcloud’: Word cloud
# - ‘umap’: UMAP Dimensionality Plot

# %% [markdown]
# <a id='SU' name="SU"></a>
# ## [Set up](#P0)

# %% [markdown]
# ### Magics

# %%
# auto reload packages and modules when they are modified
# %load_ext autoreload
# %autoreload 2
# draw matplotlib plots in line
# %matplotlib inline
# enforce PEP 8 code on jupyter lab ...
#%load_ext lab_black
# ... or jupyter notebook
#%load_ext nb_black
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Packages

# %%
# General
import pandas as pd
import numpy as np

# modelling
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import (
    CountVectorizer,
    TfidfTransformer,
    TfidfVectorizer,
)

# Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Custom classes and functions

# %%
#import sys

#SCRIPT_DIR = "../src"
#sys.path.append(SCRIPT_DIR)

# %%
#from template_module import my_function_name

# %% [markdown]
# ### Global Parameters Setting

# %%
plt.style.use("seaborn")

# %% [markdown]
# ### User-Dependent Variables

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
url_features = "gdrive/My Drive/SIDECAR_P/Sidecar_Data_Sample.csv"  # path to data file
data = pd.read_csv(url_features)

# %% [markdown]
# <a id='P1'></a>
# ## [Part one](#P0)
#
# Here you could write a paragraph on the aim of part one. You could also have some nice figures

# %%
# let's try topic modelling with pycaret 
# https://towardsdatascience.com/topic-modeling-on-pycaret-2ce0c65ba3ff
# !pip install --use-deprecated=legacy-resolver pycaret[full]

# %%
from pycaret.nlp import *
from scipy import linalg

# %%
# !python -m spacy download en_core_web_sm
# !python -m textblob.download_corpora

# %%
# initialize the setup
nlp = setup(data = data, target = "Attribute_Business_Name", session_id = 42)
# Out:
# <style type="text/css">
# </style>
# <table id="T_104f0_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_104f0_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_104f0_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <td id="T_104f0_row1_col0" class="data row1 col0" >Documents</td>
#       <td id="T_104f0_row1_col1" class="data row1 col1" >4133</td>
#     </tr>
#     <tr>
#       <td id="T_104f0_row2_col0" class="data row2 col0" >Vocab Size</td>
#       <td id="T_104f0_row2_col1" class="data row2 col1" >890</td>
#     </tr>
#     <tr>
#       <td id="T_104f0_row3_col0" class="data row3 col0" >Custom Stopwords</td>
#       <td id="T_104f0_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
lda = create_model('lda', num_topics = 10, multi_core = True)
df_lda = assign_model(lda)
df_lda.head()
# Out:
#    Domain_Id             Domain_Name  ... Dominant_Topic Perc_Dominant_Topic
# 0          1  Patient administrative  ...        Topic 6                0.70
# 1          1  Patient administrative  ...        Topic 0                0.10
# 2          1  Patient administrative  ...        Topic 5                0.70
# 3          1  Patient administrative  ...        Topic 4                0.55
# 4          1  Patient administrative  ...        Topic 0                0.55
#
# [5 rows x 49 columns]

# %%
from pycaret.utils import enable_colab
enable_colab()
# Out:
# Colab mode enabled.

# %%
plot_model(lda, plot="topic_model")
plot_model(lda, plot="topic_distribution")
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 3      0.038425 -0.012137       1        1  13.234160
# 4      0.002655 -0.454180       2        1  12.559160
# 6     -0.438587 -0.136364       3        1  12.000611
# 0     -0.178319  0.350892       4        1  10.390913
# 5      0.310171 -0.269472       5        1  10.242350
# 9      0.414137  0.017487       6        1  10.049064
# 1      0.100053  0.385892       7        1   9.812615
# 8     -0.142751 -0.234202       8        1   7.899145
# 7     -0.317123  0.137937       9        1   7.375521
# 2      0.211339  0.214148      10        1   6.436461, topic_info=            Term        Freq       Total Category  logprob  loglift
# 13          name  438.000000  438.000000  Default  30.0000  30.0000
# 1          would  470.000000  470.000000  Default  29.0000  29.0000
# 14          last  302.000000  302.000000  Default  28.0000  28.0000
# 20          date  284.000000  284.000000  Default  27.0000  27.0000
# 47        number  181.000000  181.000000  Default  26.0000  26.0000
# ..           ...         ...         ...      ...      ...      ...
# 510         make    6.384153   12.363509  Topic10  -4.5649   2.0823
# 266    attribute   40.248121  166.819725  Topic10  -2.7236   1.3213
# 755         hold    4.365242   13.208245  Topic10  -4.9450   1.6360
# 443  transaction    3.878603   57.350888  Topic10  -5.0632   0.0495
# 809         null    2.394442    6.424033  Topic10  -5.5455   1.7563
#
# [404 rows x 6 columns], token_table=      Topic      Freq       Term
# term
# 560       6  0.947144    account
# 667       2  0.512998     actual
# 667       7  0.256499     actual
# 21        6  0.983491    address
# 511       6  0.609045  addressid
# ...     ...       ...        ...
# 780       3  0.689442    website
# 86       10  0.828291     weight
# 347       8  0.929513       work
# 1         3  0.998493      would
# 233       1  0.943400       year
#
# [417 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[4, 5, 7, 1, 6, 10, 2, 9, 8, 3])
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="4466cae5-4f59-4070-b4d6-93760fb06dbb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4466cae5-4f59-4070-b4d6-93760fb06dbb")) {                    Plotly.newPlot(                        "4466cae5-4f59-4070-b4d6-93760fb06dbb",                        [{"alignmentgroup":"True","customdata":[["type, transaction, unit, tax, contact, quantity, amount, datum, price, product"],["item, source, stock, application, total, invoice, category, customer, supplier, supply"],["customer, delivery, system, datum, attribute, sample, rule, method, rate, payment"],["key, use, primary, database, reference, person, record, foreign, customer, row"],["last, date, modify, time, edit, update, record, end, start, scan"],["name, version, full, application, nullable, code, person, letter, company, first"],["would, domain, classification, attribute, asset, technical, catalog, search, object, visit"],["business, attribute, description, delete, city, group, observation, language, entity, currency"],["order, purchase, concept, date, region, sale, comment, target, server, join"],["number, country, address, value, line, product, identification, phone, condition, account"]],"hovertemplate":"Topic=%{x}<br>Documents=%{y}<br>Keyword=%{customdata[0]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Topic 0","Topic 1","Topic 2","Topic 3","Topic 4","Topic 5","Topic 6","Topic 7","Topic 8","Topic 9"],"xaxis":"x","y":[938,311,147,390,478,462,604,287,230,286],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111 ...

# %%
plot_model(lda, plot='frequency', topic_num = 'Topic 1')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="8041e402-c400-4a82-bd83-3df6c20c02a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("8041e402-c400-4a82-bd83-3df6c20c02a5")) {                    Plotly.newPlot(                        "8041e402-c400-4a82-bd83-3df6c20c02a5",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"count","orientation":"v","text":"","x":["source","item","stock","invoice","would","total","category","supplier","value","supply","number","customer","location","payment","drug","system","use","application","applicable","reason","transaction","month","date","day","description","name","reference","freeze","usually","cost","dimension","term","unit","credit","chiller","quantity","cycle","stop","manufacturing","subdivision","information","need","last","site","order","statement","route","administration","current","invoiceid","inventory","effective","brand","color","compute","concept","line","estimate","start","dry","delivery","component","receive","transport","average","assembly","vendor","expiration","shipment","process","price","isolation","hierarchy","optional","profit","population","product","pre","mutation","indication","high","height","freight","temp","corporate","female","subtotal","failure","storage","due","employee","standard","speciman","foreign","exist","key","sale","range","regularity","locationid"],"y":[60,56,44,31,26,25,21,20,19,18,18,18,18,14,13,12,12,11,11,10,9,9,8,8,8,8,7,7,6,6,6,6,6,5,5,5,5,5,5,5,5,4,4,4,4,4,4,4,4,4,4,4,4,4,4,4,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"# ...

# %% [markdown]
# ### Subsection 1
#
# This is a subsection. It can either be tagged as a hint, a solution or not tagged.

# %% [markdown]
# <div style="background:#EEEDF5;color:#303030"><div style="margin-left: .2cm">
#     <b>Comments:</b>
# </div></div>
#
# <div style="margin-left: 0.4cm">
#     This Markdown cell is a template to write extended comments. e.g. explain the approach taken, or concepts behind algorithm chosen. Aim at having 2 lines at least. Anything smaller can be directly integrated in the code, or gathered together with other comments to form a bigger paragraph. Since this block is within a div element, you need to use html formatting syntax, not markdown
# </div>

# %% [markdown]
# <div style="background:#EEEDF5;border:0.1cm solid #FDB100;color:#303030">
#     <div style="margin: 0.2cm 0.2cm 0.2cm 0.2cm">
#         <b style="color:#FDB100">Title:</b>
#         This is a an example yellow box
#     </div>
# </div>

# %% [markdown]
# <div style="background:#EEEDF5;border:0.1cm solid #00BAE5;color:#303030">
#     <div style="margin: 0.2cm 0.2cm 0.2cm 0.2cm">
#         <b style="color:#00BAE5">Note:</b>
#         This is an example Blue Box
#     </div>
# </div>

# %% [markdown]
# <div style="background:#EEEDF5;border:0.1cm solid #EF475B;color:#303030">
#     <div style="margin: 0.2cm 0.2cm 0.2cm 0.2cm">
#         <b style="color:#EF475B">Warning:</b>
#         This is an example red box
#     </div>
# </div>

# %% [markdown]
# <a id='P2' name="P2"></a>
# ## [Part 2 title here](#P0)

# %%
# initialize the setup
nlp = setup(data = data, target = "Attribute_Business_Desc", session_id = 42)
# Out:
# <style type="text/css">
# </style>
# <table id="T_15f21_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_15f21_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_15f21_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <td id="T_15f21_row1_col0" class="data row1 col0" >Documents</td>
#       <td id="T_15f21_row1_col1" class="data row1 col1" >4133</td>
#     </tr>
#     <tr>
#       <td id="T_15f21_row2_col0" class="data row2 col0" >Vocab Size</td>
#       <td id="T_15f21_row2_col1" class="data row2 col1" >1649</td>
#     </tr>
#     <tr>
#       <td id="T_15f21_row3_col0" class="data row3 col0" >Custom Stopwords</td>
#       <td id="T_15f21_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
lda = create_model('lda', num_topics = 10, multi_core = True)
df_lda = assign_model(lda)
df_lda.head()
# Out:
#    Domain_Id             Domain_Name  ... Dominant_Topic Perc_Dominant_Topic
# 0          1  Patient administrative  ...        Topic 9                0.52
# 1          1  Patient administrative  ...        Topic 8                0.48
# 2          1  Patient administrative  ...        Topic 6                0.81
# 3          1  Patient administrative  ...        Topic 7                0.54
# 4          1  Patient administrative  ...        Topic 9                0.52
#
# [5 rows x 49 columns]

# %%
plot_model(lda, plot="topic_model")
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 9      0.351778  0.206351       1        1  13.021354
# 5      0.103547  0.370679       2        1  11.757059
# 1     -0.307579 -0.285022       3        1  11.682158
# 7     -0.089534  0.311106       4        1  10.856325
# 3      0.018092 -0.394945       5        1  10.391184
# 8     -0.309641  0.175532       6        1   9.462065
# 4      0.029733 -0.152944       7        1   8.811831
# 0     -0.333913 -0.026758       8        1   8.318894
# 2      0.361316 -0.223893       9        1   8.091034
# 6      0.176200  0.019895      10        1   7.608096, topic_info=           Term        Freq       Total Category  logprob  loglift
# 66         name  362.000000  362.000000  Default  30.0000  30.0000
# 119        date  338.000000  338.000000  Default  29.0000  29.0000
# 67        would  479.000000  479.000000  Default  28.0000  28.0000
# 8        record  291.000000  291.000000  Default  27.0000  27.0000
# 102        last  251.000000  251.000000  Default  26.0000  26.0000
# ..          ...         ...         ...      ...      ...      ...
# 59         type   30.531219  222.040635  Topic10  -3.7408   0.5918
# 67        would   35.748713  479.319472  Topic10  -3.5830  -0.0199
# 993        user   16.020256   91.334316  Topic10  -4.3857   0.8353
# 30          use   16.972167  189.697608  Topic10  -4.3280   0.1621
# 157  collection    8.315552   16.004963  Topic10  -5.0414   1.9212
#
# [461 rows x 6 columns], token_table=      Topic      Freq         Term
# term
# 1009      5  0.870584       access
# 1010      5  0.946928      account
# 41        7  0.902120       active
# 78        4  0.038636      address
# 78        8  0.019318      address
# ...     ...       ...          ...
# 67        7  0.375532        would
# 67       10  0.075106        would
# 651       6  0.884329         year
# 651      10  0.088433         year
# 940       8  0.810290  young_feede
#
# [532 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[10, 6, 2, 8, 4, 9, 5, 1, 3, 7])

# %%
plot_model(lda, plot="topic_distribution")
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="a10b0cee-02a7-4e1d-87d9-2933573ebf22" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a10b0cee-02a7-4e1d-87d9-2933573ebf22")) {                    Plotly.newPlot(                        "a10b0cee-02a7-4e1d-87d9-2933573ebf22",                        [{"alignmentgroup":"True","customdata":[["classification, attribute, unit, line, audit, indicate, receive, price, result, company"],["record, last, time, update, system, date, unique, identifier, source, edit"],["name, table, business, domain, full, contact, address, customer, amount, technical"],["type, concept, datum, source, description, attribute, asset, contain, appear, category"],["would, define, asset, uniqueness, datum, visit, patient, delivery, condition, code"],["database, troop, code, transaction, include, variable, location, tax, version, tcc"],["object, would, visualization, value, death, child, type, month, conflict, hold"],["would, number, use, item, reference, stock, column, customer, invoice, status"],["date, time, country, start, end, information, payment, day, valid, available"],["key, foreign, application, person, order, primary, product, would, purchase, number"]],"hovertemplate":"Topic=%{x}<br>Documents=%{y}<br>Keyword=%{customdata[0]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Topic 0","Topic 1","Topic 2","Topic 3","Topic 4","Topic 5","Topic 6","Topic 7","Topic 8","Topic 9"],"xaxis":"x","y":[924,432,375,320,305,245,213,463,326,530],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111111111111111 ...

# %%
plot_model(lda, plot='frequency', topic_num = 'Topic 1')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="49a63144-6c68-485c-a258-7cd4bca9e1da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("49a63144-6c68-485c-a258-7cd4bca9e1da")) {                    Plotly.newPlot(                        "49a63144-6c68-485c-a258-7cd4bca9e1da",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"count","orientation":"v","text":"","x":["record","last","update","time","date","system","unique","source","identifier","edit","user","modify","indicate","would","supply","datum","obtain","name","surgery","number","download","external","person","medicine","application","asset","load","table","data","transaction","value","use","score","confirm","provide","employee","effective","type","token","invoiceid","mutation","package","store","column","available","extract","delete","salesperson","whenever","procedure","radiotherapy","change","clinical","patient","rule","psychology","device","ide","individual","generate","genetic","give","complete","identification","sample","create","condition","bear","checksum","sphn","scale","child","care","sequence","vascular","version","build","code","respecting","reference","drg","deletion","ever","example","family","hand","health","define","important","list","mother","oral","paediatric","particular","description","pharmacy","psychiatry","psychotherapy","reconstructive","adolescent"],"y":[216,211,143,138,128,105,71,71,68,65,63,56,30,17,14,13,11,10,10,9,9,9,9,8,7,7,6,6,6,6,6,5,5,5,5,5,5,5,4,4,4,4,4,4,4,4,4,4,4,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777777777 ...

# %% [markdown]
# <a id='P3' name="P3"></a>
# ## [Part 3 title here](#P0)

# %% [markdown]
# <a id='CL'></a>
# ## [Conclusion](#P0)
#
# This is a pre-written conclusion in which we have nice figures.

# %% [markdown]
# <div style="border-top:0.1cm solid #EF475B"></div>
#     <strong><a href='#Q0'><div style="text-align: right"> <h3>End of this Notebook.</h3></div></a></strong>
