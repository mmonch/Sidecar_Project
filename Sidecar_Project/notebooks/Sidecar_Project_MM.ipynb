# %% [markdown]
# <a href="https://colab.research.google.com/github/mmonch/Sidecar_Project/blob/main/Sidecar_Project/notebooks/Sidecar_Project_MM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a id='Q0'></a>
# <center><a target="_blank" href="https://sit.academy/"><img src="https://drive.google.com/uc?id=1z0U84GYqhbWWpCenFajh8_8XFRGyOc3U" width="200" style="background:none; border:none; box-shadow:none;" /></a> </center>
# <center> <h1> Notebook 1: Sidecar Data Exploration </h1> </center>
# <p style="margin-bottom:1cm;"></p>
# <center><h4>SIT Academy, 2022</h4></center>
# <p style="margin-bottom:1cm;"></p>
#
# <div style="background:#EEEDF5;border-top:0.1cm solid #EF475B;border-bottom:0.1cm solid #EF475B;">
#     <div style="margin-left: 0.5cm;margin-top: 0.5cm;margin-bottom: 0.5cm;color:#303030">
#         <p><strong>Goal:</strong> Short description of the aim of the notebook</p>
#         <strong> Outline:</strong>
#         <a id='P0' name="P0"></a>
#         <ol>
#             <li> <a style="color:#303030" href='#I'>Introduction </a> </li>
#             <li> <a style="color:#303030" href='#SU'>Set up</a></li>
#             <li> <a style="color:#303030" href='#P1'>Part 1</a></li>
#             <li> <a style="color:#303030" href='#P2'>Part 2</a></li>
#             <li> <a style="color:#303030" href='#P3'>Part 3</a></li>
#             <li> <a style="color:#303030" href='#CL'>Conclusion</a></li>
#         </ol>
#         <strong>Keywords:</strong> data cleaning, NLP, ... list of keywords.
#     </div>
# </div>
# </nav>

# %% [markdown]
# <a id='I' name="I"></a>
# ## [Introduction](#P0)

# %% [markdown]
# Sources:
#
# https://loeb.nyc/blog/data-science-word-expander
# https://towardsdatascience.com/nlp-building-text-cleanup-and-preprocessing-pipeline-eba4095245a0
# https://towardsdatascience.com/guide-to-fine-tuning-text-generation-models-gpt-2-gpt-neo-and-t5-dc5de6b3bc5e
# https://www.machinecurve.com/index.php/2020/12/29/differences-between-autoregressive-autoencoding-and-sequence-to-sequence-models-in-machine-learning/

# %% [markdown]
# <a id='SU' name="SU"></a>
# ## [Set up](#P0)

# %% [markdown]
# ### Magics

# %%
pip install nb_black
# Out:
# Collecting nb_black
#   Downloading nb_black-1.0.7.tar.gz (4.8 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from nb_black) (5.5.0)
# Collecting black>='19.3'
#   Downloading black-21.12b0-py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 5.1 MB/s
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.7/dist-packages (from black>='19.3'->nb_black) (3.10.0.2)
# Collecting platformdirs>=2
#   Downloading platformdirs-2.4.1-py3-none-any.whl (14 kB)
# Collecting tomli<2.0.0,>=0.2.6
#   Downloading tomli-1.2.3-py3-none-any.whl (12 kB)
# Collecting pathspec<1,>=0.9.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: click>=7.1.2 in /usr/local/lib/python3.7/dist-packages (from black>='19.3'->nb_black) (7.1.2)
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Collecting typed-ast>=1.4.2
#   Downloading typed_ast-1.5.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (843 kB)
#      |████████████████████████████████| 843 kB 62.3 MB/s
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->nb_black) (0.7.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->nb_black) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->nb_black) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython->nb_black) (1.0.18)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->nb_black) (5.1.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->nb_black) (4.4.2)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython->nb_black) (0.8.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->nb_black) (57.4.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->nb_black) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->nb_black) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython->nb_black) (0.7.0)
# Building wheels for collected packages: nb-black
#   Building wheel for nb-black (setup.py) ... done
#   Created wheel for nb-black: filename=nb_black-1.0.7-py3-none-any.whl size=5297 sha256=222476f72fbc9ae303598f321dca86fe3f626abb70c408df0642e8a1e883d6c4
#   Stored in directory: /root/.cache/pip/wheels/1e/b2/88/51c66d23ea5fd0d40ed50997555e15d981d92671376a9a412a
# Successfully built nb-black
# Installing collected packages: typed-ast, tomli, platformdirs, pathspec, mypy-extensions, black, nb-black
#   Attempting uninstall: tomli
#     Found existing installation: tomli 2.0.0
#     Uninstalling tomli-2.0.0:
#       Successfully uninstalled tomli-2.0.0
# Successfully installed black-21.12b0 mypy-extensions-0.4.3 nb-black-1.0.7 pathspec-0.9.0 platformdirs-2.4.1 tomli-1.2.3 typed-ast-1.5.2

# %%
# auto reload packages and modules when they are modified
# %load_ext autoreload
# %autoreload 2
# draw matplotlib plots in line
# %matplotlib inline
# enforce PEP 8 code on jupyter lab ...
#%load_ext lab_black
# ... or jupyter notebook
#%load_ext nb_black

# Colab setup ------------------
import os, sys, subprocess
if "google.colab" in sys.modules:
    cmd = "pip install --upgrade watermark blackcellmagic"
    process = subprocess.Popen(cmd.split(), stdout=subprocess.PIPE)

# %load_ext blackcellmagic

# %%
# !pip install contractions
# Out:
# Requirement already satisfied: contractions in /usr/local/lib/python3.7/dist-packages (0.1.66)
# Requirement already satisfied: textsearch>=0.0.21 in /usr/local/lib/python3.7/dist-packages (from contractions) (0.0.21)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (1.4.2)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (0.3.0)

# %%
# !pip install nltk>=3.2.1

# %% [markdown]
# ### Packages

# %%
# General
import pandas as pd
import numpy as np

# modelling
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import (
    CountVectorizer,
    TfidfTransformer,
    TfidfVectorizer,
)

# Visualization
import seaborn as sns
import matplotlib.pyplot as plt

import contractions
from bs4 import BeautifulSoup
import numpy as np
import re
import tqdm
import unicodedata

# %% [markdown]
# ### Custom classes and functions

# %%
import sys

SCRIPT_DIR = "../src"
sys.path.append(SCRIPT_DIR)

# %%
from template_module import my_function_name

# %% [markdown]
# ### Global Parameters Setting

# %%
plt.style.use("seaborn")

# %% [markdown]
# ### User-Dependent Variables

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
data = pd.read_csv("gdrive/My Drive/SIDECAR_P/Sidecar_Data_Sample.csv")

# %% [markdown]
# <a id='P1'></a>
# ## [Part one](#P0)
#
# Here you could write a paragraph on the aim of part one. You could also have some nice figures

# %%
# %load_ext google.colab.data_table

data
# Out:
# Warning: Total number of columns (37) exceeds max_columns (20). Falling back to pandas display.
#       Domain_Id             Domain_Name  ... Attribute_Status Attribute_Status_Code
# 0             1  Patient administrative  ...           Active                     1
# 1             1  Patient administrative  ...           Active                     1
# 2             1  Patient administrative  ...           Active                     1
# 3             1  Patient administrative  ...           Active                     1
# 4             1  Patient administrative  ...           Active                     1
# ...         ...                     ...  ...              ...                   ...
# 4128          7                     ICT  ...           Active                     1
# 4129          7                     ICT  ...           Active                     1
# 4130          7                     ICT  ...           Active                     1
# 4131          7                     ICT  ...           Active                     1
# 4132          7                     ICT  ...           Active                     1
#
# [4133 rows x 37 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4133 entries, 0 to 4132
# Data columns (total 37 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Domain_Id                 4133 non-null   int64
#  1   Domain_Name               4133 non-null   object
#  2   Domain_Desc               4133 non-null   object
#  3   Domain_Code               4133 non-null   object
#  4   Domain_Status             4133 non-null   object
#  5   Domain_Status_Code        4133 non-null   int64
#  6   Application_Id            4133 non-null   int64
#  7   Application_Name          4133 non-null   object
#  8   Application_Code          4133 non-null   object
#  9   Application_Desc          4133 non-null   object
#  10  Application_Status        4133 non-null   object
#  11  Application_Status_Code   4133 non-null   int64
#  12  Asset_Id                  4133 non-null   int64
#  13  Asset_Technical_Name      4133 non-null   object
#  14  Asset_Business_Name       4133 non-null   object
#  15  Asset_Business_Desc       3675 non-null   object
#  16  Asset_Status              4133 non-null   object
#  17  Asset_Status_Code         4133 non-null   int64
#  18  Asset_Server_Name         4133 non-null   object
#  19  Asset_Database            4133 non-null   object
#  20  Asset_Schema              4133 non-null   object
#  21  Asset_Type_Id             4133 non-null   int64
#  22  Asset_Type_Name           4133 non-null   object
#  23  Asset_Type_Desc           4133 non-null   object
#  24  Privacy_Level_Id          4133 non-null   int64
#  25  Asset_Privacy_Level       4133 non-null   object
#  26  Asset_Privacy_Desc        4133 non-null   object
#  27  Attribute_Id              4133 non-null   int64
#  28  Attribute_Technical_Name  4133 non-null   object
#  29  Attribute_Business_Name   4133 non-null   object
#  30  Attribute_Business_Desc   3726 non-null   object
#  31  Attribute_Business_Rule   350 non-null    object
#  32  Attribute_Data_Type       4130 non-null   object
#  33  Attribute_IsPK            4133 non-null   object
#  34  Attribute_IsNullable      4133 non-null   object
#  35  Attribute_Status          4133 non-null   object
#  36  Attribute_Status_Code     4133 non-null   int64
# dtypes: int64(10), object(27)
# memory usage: 1.2+ MB

# %%
data.describe()
# Out:
#          Domain_Id  Domain_Status_Code  ...  Attribute_Id  Attribute_Status_Code
# count  4133.000000              4133.0  ...   4133.000000            4133.000000
# mean      7.288168                 1.0  ...   2173.253327               1.009436
# std       3.175863                 0.0  ...   1294.975998               0.136184
# min       1.000000                 1.0  ...      1.000000               1.000000
# 25%       7.000000                 1.0  ...   1039.000000               1.000000
# 50%       7.000000                 1.0  ...   2145.000000               1.000000
# 75%       7.000000                 1.0  ...   3195.000000               1.000000
# max      19.000000                 1.0  ...   4460.000000               3.000000
#
# [8 rows x 10 columns]

# %%
data.isnull().any()

# %%
is_na = data[data.isna().any(axis=1)]

# %%
len(is_na)
# Out:
# 3792

# %%
is_na.tail()
# Out:
# Warning: Total number of columns (37) exceeds max_columns (20). Falling back to pandas display.
#       Domain_Id Domain_Name  ... Attribute_Status Attribute_Status_Code
# 4128          7         ICT  ...           Active                     1
# 4129          7         ICT  ...           Active                     1
# 4130          7         ICT  ...           Active                     1
# 4131          7         ICT  ...           Active                     1
# 4132          7         ICT  ...           Active                     1
#
# [5 rows x 37 columns]

# %%
np.sort(data["Asset_Id"].unique())

# %%
# how many values per column, value_counts() per feature
for col in data.columns:
  print (f"Column Name, Number of unique values: \n{col}, {data[col].nunique()}\nValue Counts: \n{data[col].value_counts()}\n\n----------------------")
# Out:
# Column Name, Number of unique values:
# Domain_Id, 8
# Value Counts:
# 7     2700
# 11     508
# 1      302
# 12     269
# 2      258
# 19      60
# 14      22
# 10      14
# Name: Domain_Id, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Domain_Name, 8
# Value Counts:
# ICT                            2700
# Clinical Research               508
# Patient administrative          302
#  Humanitarian Data Exchange     269
# Biobank                         258
# Master Data                      60
# Insurance                        22
# Infectious Diseases              14
# Name: Domain_Name, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Domain_Desc, 8
# Value Counts:
# ICT department                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    2700
# Data sets may be used for prevention, treatment, diagnosis or for relieving symptoms of a disease                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  508
# Patient administrative data (demographic & administration).                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        302
# The Humanitarian Data Exchange (HDX) is an open platform for sharing data across crises and organisations. Launched in July 2014, the goal of HDX is to make humanitarian data easy to find and use for analysis. Our growing collection of datasets has been accessed by users in over 200 countries and territories.\n\nHDX is managed by OCHA's Centre for Humanitarian Data, which is located in The Hague. OCHA is part of the United Nations Secretariat and is responsible for bringing together humanitarian actors to ensure a coherent response to emergencies. The HDX team includes OCHA staff and a number of consultants who are based in North America, Europe and Africa.\n//data.humdata.org/     269
# Biorepository that stores biological samples (usually human) for use in research. Biobanks have become an important resource in medical research, supporting many types of contemporary research like genomics and personalized medicine. Biobanks can give researchers access to data representing a large number of people.                                                                                                                                                                                                                                                                                                                                                                                      258
# Institutional master data                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           60
# Insurance on personal risk, such as car insurance, health insurance or loss of earnings insurance                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   22
# Data related to infectious diseases. Diagnosis and treatment of acute and chronic infectious diseases. Frequently infections are the cause of swollen lymph glands, night sweats and weight loss.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   14
# Name: Domain_Desc, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Domain_Code, 8
# Value Counts:
# ICT        2700
# RES         508
# PAT_ADM     302
# HXL         269
# BIOB        258
# MDM          60
# Ins          22
# INF          14
# Name: Domain_Code, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Domain_Status, 1
# Value Counts:
# Active    4133
# Name: Domain_Status, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Domain_Status_Code, 1
# Value Counts:
# 1    4133
# Name: Domain_Status_Code, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Application_Id, 21
# Value Counts:
# 15    1023
# 51     744
# 52     501
# 53     432
# 1      302
# 17     268
# 54     186
# 26      87
# 24      85
# 18      77
# 23      64
# 25      62
# 19      61
# 55      60
# 22      54
# 20      54
# 56      20
# 5       17
# 27      14
# 16      14
# 28       8
# Name: Application_Id, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Application_Name, 21
# Value Counts:
# sidecar                                       1023
# AdventureWorks                                 744
# WideWorldImporters DWH                         501
# WideWorldImporters                             432
# Patient Manager                                302
# I2B2                                           268
# Observational Medical Outcomes Partnership     186
# ICRC                                            87
# Unicef                                          85
# Uppsala                                         77
# Tissue-DS                                       64
# Liquid-DS                                       62
# Vet-DS                                          61
# Country                                         60
# SPHN Dataset                                    54
# Bacteria-DS                                     54
# Unhcr                                           20
# LimsLab                                         17
# OutbreakTools                                   14
# Car insurance                                   14
# Public Property Damaged                          8
# Name: Application_Name, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Application_Code, 21
# Value Counts:
# SIDECAR    1023
# ADW         744
# WWI         501
# WWIT        432
# PATMAN      302
# I2B2        268
# OMOP        186
# ICRC         87
# UNICEF       85
# UPPSALA      77
# TISSUE       64
# LIQUID       62
# VET          61
# COUNTRY      60
# SPHN         54
# BAC          54
# UNHCR        20
# SLIMS        17
# OUTBRK       14
# Car          14
# Pub           8
# Name: Application_Code, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Application_Desc, 21
# Value Counts:
# sidecar is metadata management system.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1023
# Sample database from Microsoft                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        744
# Wide World Importers for data warehouse                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               501
# Wide World Importers transactional                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    432
# Patient Manager tool is the application allowing administrative management of the patient. It is connected to several clinical applications and is considered to be the backbone of the Information.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  302
# Informatics for Integrating Biology & the Bedside. i2b2 is an open-source clinical data warehousing and analytics research platform used at over 250 locations worldwide. i2b2 enables sharing, integration, standardization, and analysis of heterogenous data from healthcare and research. \r\n https://www.i2b2.org/                                                                                                                                                                                                                                                                                                                                                                                                                              268
# The Observational Medical Outcomes Partnership (OMOP) Common Data Model (CDM) is an open community data standard, designed to standardize the structure and content of observational data and to enable efficient analyses that can produce reliable evidence. A central component of the OMOP CDM is the OHDSI standardized vocabularies. The OHDSI vocabularies allow organization and standardization of medical terms to be used across the various clinical domains of the OMOP common data model and enable standardized analytics that leverage the knowledge base when constructing exposure and outcome phenotypes and other features within characterization, population-level effect estimation, and patient-level prediction studies.     186
# The International Federation of Red Cross and Red Crescent Societies (IFRC) is the world's largest humanitarian organization, with 190 member National Societies. As part of the International Red Cross and Red Crescent Movement, our work is guided by seven fundamental principles; humanity, impartiality, neutrality, independence, voluntary service, unity and universality.                                                                                                                                                                                                                                                                                                                                                                   87
# Unicef open data \r\n source: https://data.unicef.org/open-data/ \r\nDeploying open data tools and standards to support UNICEF global public indicators                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                85
# The Uppsala Conflict Data Program is a data collection program on organized violence, based at Uppsala University in Sweden. The UCDP is a leading provider of data on organized violence and armed conflict, and it is the oldest ongoing data collection project for civil war, with a history of almost 40 years.                                                                                                                                                                                                                                                                                                                                                                                                                                   77
# Biobanking Data of Tissue Specimen \r\nPreanalytics Tissue Specimen \r\nAll Elements detailed                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          64
# Biobanking Data of Liquid Specimen \r\nPreanalytics Tissue Specimen \r\nAll Elements detailed                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          62
# Veterinary Dataset Preanalytics Liquid & Tissue. It contains variables related to the animal and the specimen covering all biobanking processes from collection to distribution.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       61
# Country master data                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    60
# This dataset contains the core and extended concepts. The core concepts represent the hospital mandate of the SPHN. It will be used for feasibility studies.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           54
# Data set for Biobanking of microbiological specimen - Preanalytics for Bacteria                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        54
# United Nations High Commissioner for Refugees                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          20
# LimsLab is an integrated Laboratory Information Management System (LIMS) and Electronic Laboratory Notebook (ELN) with comprehensive Workflow Management capabilities in one solution. Its designed to be flexible and configurable enabling every lab to configure the system to match its processes and procedures.                                                                                                                                                                                                                                                                                                                                                                                                                                  17
# Outbreak risk software safeguards lives by mitigating exposure to infectious diseases that threaten human health, security, and prosperity.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            14
# Financial protection against loss as a result of an automobile accident or theft                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       14
# Tracks the collection public property damaged                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           8
# Name: Application_Desc, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Application_Status, 1
# Value Counts:
# Active    4133
# Name: Application_Status, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Application_Status_Code, 1
# Value Counts:
# 1    4133
# Name: Application_Status_Code, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Asset_Id, 381
# Value Counts:
# 13     192
# 409     71
# 113     49
# 411     47
# 151     43
#       ...
# 413      2
# 88       2
# 45       2
# 29       1
# 345      1
# Name: Asset_Id, Length: 381, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Asset_Technical_Name, 364
# Value Counts:
# PMS_RECORD              192
# v_Full_Hierarchy         71
# Geo_PKO_12               49
# v_Data_Asset             47
# DC_OP4_DANA              43
#                        ...
# concept_Death Status      2
# concept_Location          2
# concept_Rate              2
# Bac_Ref                   1
# note_nlp                  1
# Name: Asset_Technical_Name, Length: 364, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Asset_Business_Name, 344
# Value Counts:
# Patient record                                                                   192
# View full hierarchy                                                               71
# People known to the application (staff, customer contacts, supplier contacts)     63
# Main entity tables for customers (organizations or individuals)                   62
# Main entity table for suppliers (organizations)                                   58
#                                                                                 ...
# Rate                                                                               2
# ETL Cutoff Times                                                                   2
# Qt analysis plugin result type                                                     2
# References                                                                         1
# Note nlp                                                                           1
# Name: Asset_Business_Name, Length: 344, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Asset_Business_Desc, 311
# Value Counts:
# Patient record for a specific visit                                                                                                                                                                                                                                                                                                                                                                                                                                                                               192
# This view contains the entire hierarchy of objects, from the domain to the attribute.                                                                                                                                                                                                                                                                                                                                                                                                                              71
# People known to the application (staff, customer contacts, supplier contacts)                                                                                                                                                                                                                                                                                                                                                                                                                                      63
# Main entity tables for customers (organizations or individuals)                                                                                                                                                                                                                                                                                                                                                                                                                                                    62
# Contains the list of attributes that characterize a data asset. The information associated to an attribute are generally split into two categories. The first one contains the technical information of the attribute (type,  is null, ...), this information is automatically added and updated by sidecar. The second category concerns the functional information of the attribute, it is maintained by the users. The database attributes are added automatically through the "Asset list search" process.     59
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# Qt analysis plugin result type table                                                                                                                                                                                                                                                                                                                                                                                                                                                                                2
# physical location or medical division taking care of the individual - Type: - Value set: self                                                                                                                                                                                                                                                                                                                                                                                                                       2
# ETL Cutoff Times                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    2
# References of the specimen                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# The NOTE_NLP table will encode all output of NLP on clinical notes. Each row represents a single extracted term from a note.                                                                                                                                                                                                                                                                                                                                                                                        1
# Name: Asset_Business_Desc, Length: 311, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Asset_Status, 2
# Value Counts:
# Active    4116
# Hidden      17
# Name: Asset_Status, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Asset_Status_Code, 2
# Value Counts:
# 1    4116
# 3      17
# Name: Asset_Status_Code, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Asset_Server_Name, 9
# Value Counts:
# DESKTOP-5JVNT8I    3420
# SWT01_PRD           247
# BIO_ZH_PRD          180
# EXTNY01P             85
# BB_BERN_PRD          61
# DWH01_PRD            55
# SPHN_NODE1           54
# SWY03_PRD            17
# SWG12_PRD            14
# Name: Asset_Server_Name, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Asset_Database, 18
# Value Counts:
# sidecar_Dev             1023
# AdventureWorks2019       744
# WideWorldImporters       581
# WideWorldImportersDW     352
# I2B2                     268
# SampleData               266
# PMS                      247
# OMOP                     186
# DSTIS                    126
# Unicef                    85
# VET                       61
# SPHN_BD                   54
# BACTBio                   54
# STAGING                   35
# SLM                       17
# DB1                       14
# BI                        10
# DWH                       10
# Name: Asset_Database, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Asset_Schema, 17
# Value Counts:
# dbo               2140
# Sales              406
# Application        298
# Production         210
# Purchasing         177
# Integration        172
# HumanResources     119
# Person              94
# Dimension           91
# Fact                89
# ICRC                87
# uppsala             77
# iso                 60
# bac                 54
# ins                 22
# unhcr               20
# ref                 17
# Name: Asset_Schema, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Asset_Type_Id, 2
# Value Counts:
# 1    3350
# 2     783
# Name: Asset_Type_Id, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Asset_Type_Name, 2
# Value Counts:
# Table    3350
# View      783
# Name: Asset_Type_Name, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Asset_Type_Desc, 2
# Value Counts:
# Database table    3350
# Database view      783
# Name: Asset_Type_Desc, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Privacy_Level_Id, 5
# Value Counts:
# -1    3222
#  1     575
#  4     298
#  2      30
#  3       8
# Name: Privacy_Level_Id, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Asset_Privacy_Level, 5
# Value Counts:
# Not defined                   3222
# Level 1 - Public               575
# Level 4 - Highly sensitive     298
# Level 2 - Confidential          30
# Level 3 - Restricted             8
# Name: Asset_Privacy_Level, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Asset_Privacy_Desc, 5
# Value Counts:
# -                                             3222
# Public - everyone can see the information.     575
# Highly sensitive - Internal use                298
# Confidential - top confidentiality level        30
# Restricted - medium confidentiality level        8
# Name: Asset_Privacy_Desc, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Attribute_Id, 4133
# Value Counts:
# 2047    1
# 481     1
# 2592    1
# 541     1
# 2588    1
#        ..
# 1210    1
# 3255    1
# 1206    1
# 3251    1
# 2049    1
# Name: Attribute_Id, Length: 4133, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Attribute_Technical_Name, 1998
# Value Counts:
# ModifiedDate          73
# SYS_LastModified      49
# LastEditedBy          49
# SYS_LastModifiedBy    46
# ValidTo               38
#                       ..
# P_AF189430             1
# ProductAssemblyID      1
# cause_source_value     1
# DEM_Life_Birth_70      1
# STG_BIR_PLC            1
# Name: Attribute_Technical_Name, Length: 1998, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Attribute_Business_Name, 2099
# Value Counts:
# Date and time the record was last updated.    70
# Last modified date                            58
# Last modified by                              52
# Last Edited By                                49
# Valid to                                      38
#                                               ..
# procedure occurrence id                        1
# Audit DQ Object Type Name                      1
# Delete date                                    1
# Contact information                            1
# Column code                                    1
# Name: Attribute_Business_Name, Length: 2099, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Attribute_Business_Desc, 2094
# Value Counts:
# Date and time the record was last updated.                                                                                                                                                                                                                                                                                                                                                                                                70
# Stores the date on which the record was updated for the last time.                                                                                                                                                                                                                                                                                                                                                                        52
# User of the Last edit                                                                                                                                                                                                                                                                                                                                                                                                                     49
# Unique identifier of the user who modified the record.                                                                                                                                                                                                                                                                                                                                                                                    46
# Date valid to                                                                                                                                                                                                                                                                                                                                                                                                                             38
#                                                                                                                                                                                                                                                                                                                                                                                                                                           ..
# Estimated manufacturing cost.                                                                                                                                                                                                                                                                                                                                                                                                              1
# Actual end date.                                                                                                                                                                                                                                                                                                                                                                                                                           1
# Location of the damage. \nFull address ( County, street, number,etc...)                                                                                                                                                                                                                                                                                                                                                                    1
# general location type; can be within a hospital (department) or outside (home, retirement home). \r\n[Diagnostic institution; Accident and Emergency department; Health Authority; Private home-based care; Hospital; Military health institution; Prison based care site; Nursing home; Pharmacy; Ambulatory care site; Rehabilitation hospital; Client's or patient's home; Medical center; General practice premises; Site of care]     1
# number of events, \r\ne.g. number of heart beats                                                                                                                                                                                                                                                                                                                                                                                           1
# Name: Attribute_Business_Desc, Length: 2094, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Attribute_Business_Rule, 201
# Value Counts:
# RT\r\nControlled RT \r\n2 - 10 °C\r\n(-35) to (-18) °C\r\n(-85) to (-60) °C / dry ice\r\nLN\r\nUNK\r\nType:Mandatory         13
# Alphanumeric\r\nType:Mandatory                                                                                               11
# String of characters\r\nType:Recommended                                                                                     11
# Data exchange format: No, \r\nPrioritization: Recommended                                                                    11
# Expressed per 1,000 live births.                                                                                              8
#                                                                                                                              ..
# Tumor\r\nNormal\r\nNormal adjacent\r\nNormal distant\r\nMetastasis\r\nDiseased\r\nUNK\r\nType:Mandatory                       1
# Type: [specific consent; general consent; waiver]                                                                             1
# Sum of “Upheld Complains”, “Question of Facts Complaints”, and “Not Upheld Complaints”.                                       1
# DMSO 10%\r\nTE buffer\r\nH2O\r\nNone\r\nOther\r\nType:Recommended                                                             1
# Number of upheld complaints divided by the average of a company's current and prior year premiums written directly in NYS     1
# Name: Attribute_Business_Rule, Length: 201, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Attribute_Data_Type, 155
# Value Counts:
# int                1067
# nvarchar (25)       352
# datetime2           244
# nvarchar (50)       240
# datetime            224
#                    ...
# numeric (38,6)        1
# varchar(35)           1
# nvarchar (250)        1
# nvarchar (1925)       1
# BIT                   1
# Name: Attribute_Data_Type, Length: 155, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Attribute_IsPK, 2
# Value Counts:
# No     3884
# Yes     249
# Name: Attribute_IsPK, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Attribute_IsNullable, 2
# Value Counts:
# No     2222
# Yes    1911
# Name: Attribute_IsNullable, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Attribute_Status, 3
# Value Counts:
# Active    4113
# Hidden      19
# Draft        1
# Name: Attribute_Status, dtype: int64
#
# ----------------------
# Column Name, Number of unique values:
# Attribute_Status_Code, 3
# Value Counts:
# 1    4113
# 3      19
# 2       1
# Name: Attribute_Status_Code, dtype: int64
#
# ----------------------

# %%
data["Attribute_Technical_Name"].value_counts()
# Out:
# ModifiedDate          73
# SYS_LastModified      49
# LastEditedBy          49
# SYS_LastModifiedBy    46
# ValidTo               38
#                       ..
# P_AF189430             1
# ProductAssemblyID      1
# cause_source_value     1
# DEM_Life_Birth_70      1
# STG_BIR_PLC            1
# Name: Attribute_Technical_Name, Length: 1998, dtype: int64

# %%
data["Attribute_Technical_Name"].astype(str)
# Out:
# 0                                 ID
# 1                            GNDR_CD
# 2                    LIVG_ARNGMNT_CD
# 3                       MRTL_STUS_CD
# 4                         OCUPATN_CD
#                     ...
# 4128    Config_AssetList_Data_Source
# 4129           Attribute_Sample_Data
# 4130                   Property_IsDQ
# 4131         Property_DQ_Calculation
# 4132       Property_DQ_Output_Format
# Name: Attribute_Technical_Name, Length: 4133, dtype: object

# %% [markdown]
# ### Exploring Basic Models
#
# First we will try to generate the Business Name from the technical name, which should be a relatively straightforward problem.
#
# There are two basic approaches we can try.
#
# 1. Similarity-based Model
# 2. Rule-based Model

# %% [markdown]
# Text preprocessing:
# - try removing contractions (last step)
# - strip whitespaces
# - remove underscores
# - evtl. remove numbers (if it makes sense, for some data sets that might be a terrible idea --> genetic data/loci information etc.)
# - remove accentuation
# - remove special characters
# - evtl. remove punctuation
# - is lemmatization possible?
# - remove tabs (if there even are any)
# - change everything to lowercase
# - IDEA: Use probabilistic word expansion [source](https://loeb.nyc/blog/data-science-word-expander) (Word_expander) to expand abbreviated technical names? Symspell

# %%
# replace _ with space
# Out:
# 'config'

# %%
# preprocess Text

# in case text not english
def remove_accented_chars(text):
  text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
  return text

# preprocessing steps
  # remove excess white spaces
  # remove underscores
  # tokenize words
def pre_process_corpus(docs):
  norm_docs = []
  for string in tqdm.tqdm(docs):
    string = string.replace("_", " ")
    string = string.translate(string.maketrans("\n\t\r", "   "))
    string = string.lower()
    string = remove_accented_chars(string)
    string = contractions.fix(string)
    # lower case and remove special characters\whitespaces
    string = re.sub(r'[^a-zA-Z0-9\s]', '', string, flags=re.I|re.A)
    string = string.strip()
    norm_docs.append(string)

  return norm_docs

# %%
data["Attribute_Technical_Name"]
# Out:
# 0                                 ID
# 1                            GNDR_CD
# 2                    LIVG_ARNGMNT_CD
# 3                       MRTL_STUS_CD
# 4                         OCUPATN_CD
#                     ...
# 4128    Config_AssetList_Data_Source
# 4129           Attribute_Sample_Data
# 4130                   Property_IsDQ
# 4131         Property_DQ_Calculation
# 4132       Property_DQ_Output_Format
# Name: Attribute_Technical_Name, Length: 4133, dtype: object

# %%
prep_data = pre_process_corpus(data["Attribute_Technical_Name"])
# Out:
# 100%|██████████| 4133/4133 [00:00<00:00, 87133.61it/s]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-8a1df15a5b20> in <module>()
# ----> 1 np.dtype(prep_data)
#
# TypeError: Field elements must be 2- or 3-tuples, got ''id''

# %%
pip install git+https://github.com/NBCLab/abbr
# Out:
# Collecting git+https://github.com/NBCLab/abbr
#   Cloning https://github.com/NBCLab/abbr to /tmp/pip-req-build-m96m64i_
#   Running command git clone -q https://github.com/NBCLab/abbr /tmp/pip-req-build-m96m64i_
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.7/dist-packages (from abbr==0.0.1a0) (3.2.5)
# Requirement already satisfied: pandas>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from abbr==0.0.1a0) (1.1.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk>=3.2.1->abbr==0.0.1a0) (1.15.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18.1->abbr==0.0.1a0) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18.1->abbr==0.0.1a0) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18.1->abbr==0.0.1a0) (2018.9)

# %%
import abbr

# %%
from abbr import findall, expandall

# %%
prep_data = " ".join(prep_data)

expand_abbr = expandall(prep_data)

# %%
expand_abbr
# Out:
# 'id gndr cd livg arngmnt cd mrtl stus cd ocupatn cd prmry cse of dth cd pt stus cd relgn cd ttl cd vet stus cd vip cd bir ord bir plc frst nm login user id lst nm mid nm mothrs mdn nm plc of dth cit pt nbr suf decd flg bir dt decd dt email ad checksum dat src num id created by user ds num id changed by user ds num id src biz ky enterprise id insert dt src eff from dt src eff to dt correction flg stg id stg gndr cd stg livg arngmnt cd stg mrtl stus cd stg ocupatn cd stg prmry cse of dth cd stg pt stus cd stg relgn cd stg ttl cd stg vet stus cd stg vip cd stg bir ord stg bir plc stg frst nm stg login user id stg lst nm stg mid nm stg mothrs mdn nm stg plc of dth cit stg pt nbr stg suf stg decd flg stg bir dt stg decd dt stg email ad stg checksum stg dat src num id stg created by user ds num id stg changed by user ds num id stg src biz ky stg enterprise id stg insert dt stg src eff from dt stg src eff to dt stg correction flg patient id patient lastname patient firstname patient gender code patient birthdate patient deceased flg patient religion code patient email patient login patient marital status patient id patient lastname patient firstname patient gender cd patient birthdate patient deceased flg patient religion code patient email patient login patient marital status ctry id ctry code ctry iso code ctry name ctry phone prefix stg ctry id stg ctry code stg ctry iso code stg ctry name stg ctry phone prefix country id country code country iso code country name country phone prefix country id country code country iso code country name country phone prefix species name species id strain name laboratory id specimen lab id specimen external id biosafety level specimen lab id mutations wgs availability genbank accession nb other genotype information specimen lab id storage format storage temperature derivative type freeze thaw cycle p af189300 p af189301 p af189302 p af189303 p af189304 p af189305 p af189306 p af189307 p af189308 p af189309 p af189310 p af189311 p af189312 p af189313 p af189314 p af189315 p af189316 p af189317 p af189318 p af189319 p af189320 p af189321 p af189322 p af189323 p af189324 p af189325 p af189326 p af189327 p af189328 p af189329 p af189330 p af189331 p af189332 p af189333 p af189334 p af189335 p af189336 p af189337 p af189338 p af189339 p af189340 p af189341 p af189342 p af189343 p af189344 p af189345 p af189346 p af189347 p af189348 p af189349 p af189350 p af189351 p af189352 p af189353 p af189354 p af189355 p af189356 p af189357 p af189358 p af189359 p af189360 p af189361 p af189362 p af189363 p af189364 p af189365 p af189366 p af189367 p af189368 p af189369 p af189370 p af189371 p af189372 p af189373 p af189374 p af189375 p af189376 p af189377 p af189378 p af189379 p af189380 p af189381 p af189382 p af189383 p af189384 p af189385 p af189386 p af189387 p af189388 p af189389 p af189390 p af189391 p af189392 p af189393 p af189394 p af189395 p af189396 p af189397 p af189398 p af189399 p af189400 p af189401 p af189402 p af189403 p af189404 p af189405 p af189406 p af189407 p af189408 p af189409 p af189410 p af189411 p af189412 p af189413 p af189414 p af189415 p af189416 p af189417 p af189418 p af189419 p af189420 p af189421 p af189422 p af189423 p af189424 p af189425 p af189426 p af189427 p af189428 p af189429 p af189430 p af189431 p af189432 p af189433 p af189434 p af189435 p af189436 p af189437 p af189438 p af189439 p af189440 p af189441 p af189442 p af189443 p af189444 p af189445 p af189446 p af189447 p af189448 p af189449 p af189450 p af189451 p af189452 p af189453 p af189454 p af189455 p af189456 p af189457 p af189458 p af189459 p af189460 p af189461 p af189462 p af189463 p af189464 p af189465 p af189466 p af189467 p af189468 p af189469 p af189470 p af189471 p af189472 p af189473 p af189474 p af189475 p af189476 p af189477 p af189478 p af189479 p af189480 p af189481 p af189482 p af189483 p af189484 p af189485 p af189486 p af189487 p af189488 p af189489 p af189490 p af189491 fips admin2 province state c ...

# %%
# install autocorrect
# !pip install autocorrect
# Out:
# Collecting autocorrect
#   Downloading autocorrect-2.6.1.tar.gz (622 kB)
#      |████████████████████████████████| 622 kB 5.0 MB/s
# Building wheels for collected packages: autocorrect
#   Building wheel for autocorrect (setup.py) ... done
#   Created wheel for autocorrect: filename=autocorrect-2.6.1-py3-none-any.whl size=622382 sha256=6414ee5b2e6c6c37d6291fc41246ceade17c553ba14cb0491f1a712fd70e2f70
#   Stored in directory: /root/.cache/pip/wheels/54/d4/37/8244101ad50b0f7d9bffd93ce58ed7991ee1753b290923934b
# Successfully built autocorrect
# Installing collected packages: autocorrect
# Successfully installed autocorrect-2.6.1

# %%
from autocorrect import Speller
# autocorrect will run faster as a numpy array

# %%
def autocorrect(doc):
  autocorr_doc = []
  spell = Speller() #spell(data)
  # use lambda function and list comprehension to loop over strings
  autocorr_text = [spell(x) for x in doc]
  autocorr_doc.append(autocorr_text)
  return autocorr_text #autocorr_doc

# %%
autocorrect(prep_data)
# Out:
# ['id',
#  'gnd cd',
#  'live argent cd',
#  'rtl stub cd',
#  'occupant cd',
#  'primary cse of th cd',
#  'pt stub cd',
#  'reign cd',
#  'ttl cd',
#  'vet stub cd',
#  'vip cd',
#  'bir ord',
#  'bir plc',
#  'first nm',
#  'login user id',
#  'lst nm',
#  'mid nm',
#  'mothers mdn nm',
#  'plc of th cit',
#  'pt nbr',
#  'sup',
#  'dead flag',
#  'bir dt',
#  'dead dt',
#  'email ad',
#  'checks',
#  'dat src num id',
#  'created by user ds num id',
#  'changed by user ds num id',
#  'src biz ky',
#  'enterprise id',
#  'insert dt',
#  'src eff from dt',
#  'src eff to dt',
#  'correction flag',
#  'stg id',
#  'stg gnd cd',
#  'stg live argent cd',
#  'stg rtl stub cd',
#  'stg occupant cd',
#  'stg primary cse of th cd',
#  'stg pt stub cd',
#  'stg reign cd',
#  'stg ttl cd',
#  'stg vet stub cd',
#  'stg vip cd',
#  'stg bir ord',
#  'stg bir plc',
#  'stg first nm',
#  'stg login user id',
#  'stg lst nm',
#  'stg mid nm',
#  'stg mothers mdn nm',
#  'stg plc of th cit',
#  'stg pt nbr',
#  'stg sup',
#  'stg dead flag',
#  'stg bir dt',
#  'stg dead dt',
#  'stg email ad',
#  'stg checks',
#  'stg dat src num id',
#  'stg created by user ds num id',
#  'stg changed by user ds num id',
#  'stg src biz ky',
#  'stg enterprise id',
#  'stg insert dt',
#  'stg src eff from dt',
#  'stg src eff to dt',
#  'stg correction flag',
#  'patient id',
#  'patient lastname',
#  'patient firstname',
#  'patient gender code',
#  'patient birthdate',
#  'patient deceased flag',
#  'patient religion code',
#  'patient email',
#  'patient login',
#  'patient marital status',
#  'patient id',
#  'patient lastname',
#  'patient firstname',
#  'patient gender cd',
#  'patient birthdate',
#  'patient deceased flag',
#  'patient religion code',
#  'patient email',
#  'patient login',
#  'patient marital status',
#  'try id',
#  'try code',
#  'try iso code',
#  'try name',
#  'try phone prefix',
#  'stg try id',
#  'stg try code',
#  'stg try iso code',
#  'stg try name',
#  'stg try phone prefix',
#  'country id',
#  'country code',
#  'country iso code',
#  'country name',
#  'country phone prefix',
#  'country id',
#  'country code',
#  'country iso code',
#  'country name',
#  'country phone prefix',
#  'species name',
#  'species id',
#  'strain name',
#  'laboratory id',
#  'specimen lab id',
#  'specimen external id',
#  'biosafety level',
#  'specimen lab id',
#  'mutations',
#  'was availability',
#  'genbank accession nb',
#  'other genotype information',
#  'specimen lab id',
#  'storage format',
#  'storage temperature',
#  'derivative type',
#  'freeze thaw cycle',
#  'p af189300',
#  'p af189301',
#  'p af189302',
#  'p af189303',
#  'p af189304',
#  'p af189305',
#  'p af189306',
#  'p af189307',
#  'p af189308',
#  'p af189309',
#  'p af189310',
#  'p af189311',
#  'p af189312',
#  'p af189313',
#  'p af189314',
#  'p af189315',
#  'p af189316',
#  'p af189317',
#  'p af189318',
#  'p af189319',
#  'p af189320',
#  'p af189321',
#  'p af189322',
#  'p af189323',
#  'p af189324',
#  'p af189325',
#  'p af189326',
#  'p af189327',
#  'p af189328',
#  'p af189329',
#  'p af189330',
#  'p af189331',
#  'p af189332',
#  'p af189333',
#  'p af189334',
#  'p af189335',
#  'p af189336',
#  'p af189337',
#  'p af189338',
#  'p af189339',
#  'p af189340',
#  'p af189341',
#  'p af189342',
#  'p af189343',
#  'p af189344',
#  'p af189345',
#  'p af189346',
#  'p af189347',
#  'p af189348',
#  'p af189349',
#  'p af189350',
#  'p af189351',
#  'p af189352',
#  'p af189353',
#  'p af189354',
#  'p af189355',
#  'p af189356',
#  'p af189357',
#  'p af189358',
#  'p af189359',
#  'p af189360',
#  'p af189361',
#  'p af189362',
#  'p af189363',
#  'p af189364',
#  'p af189365',
#  'p af189366',
#  'p af189367',
#  'p af189368',
#  'p af189369',
#  'p af189370',
#  'p af189371',
#  'p af189372',
#  'p af189373',
#  'p af189374',
#  'p af189375',
#  'p af189376',
#  'p af189377',
#  'p af189378',
#  'p af189379',
#  'p af189380',
#  'p af189381',
#  'p af189382',
#  'p af189383',
#  'p af189384',
#  'p af189385',
#  'p af189386',
#  'p af189387',
#  'p af189388',
#  'p af189389',
#  'p af189390',
#  'p af189391',
#  'p af189392',
#  'p af189393',
#  'p af189394',
#  'p af189395',
#  'p af189396',
#  'p af189397',
#  'p af189398',
#  'p af189399',
#  'p af189400',
#  'p af189401',
#  'p af189402',
#  'p af189403',
#  'p af189404',
#  'p af189405',
#  'p af189406',
#  'p af189407',
#  'p af189408',
#  'p af189409',
#  'p af189410',
#  'p af189411',
#  'p af189412',
#  'p af189413',
#  'p af189414',
#  'p af189415',
#  'p af189416',
#  'p af189417',
#  'p af189418',
#  'p af189419',
#  'p af189420',
#  'p af189421',
#  'p af189422',
#  'p af189423',
#  'p af189424',
#  'p af189425',
#  'p af189426',
#  'p af189427',
#  'p af189428',
#  'p af189429',
#  'p af189430',
#  'p af189431',
#  'p af189432',
#  'p af189433',
#  'p af189434',
#  'p af189435',
#  'p af189436',
#  'p af189437',
#  'p af189438',
#  'p af189439',
#  'p af189440',
#  'p af189441',
#  'p af189442',
#  'p af189443',
#  'p af189444',
#  'p af189445',
#  'p af189446',
#  'p af189447',
#  'p af189448',
#  'p af189449',
#  'p af189450',
#  'p af189451',
#  'p af189452',
#  'p af189453',
#  'p af189454',
#  'p af189455',
#  'p af189456',
#  'p af189457',
#  'p af189458',
#  'p af189459',
#  'p af189460',
#  'p af189461',
#  'p af189462',
#  'p af189463',
#  'p af189464',
#  'p af189465',
#  'p af189466',
#  'p af189467',
#  'p af189468',
#  'p af189469',
#  'p af189470',
#  'p af189471',
#  'p af189472',
#  'p af189473',
#  'p af189474',
#  'p af189475',
#  'p af189476',
#  'p af189477',
#  'p af189478',
#  'p af189479',
#  'p af189480',
#  'p af189481',
#  'p af189482',
#  'p af189483',
#  'p af189484',
#  'p af189485',
#  'p af189486',
#  'p af189487',
#  'p af189488',
#  'p af189489',
#  'p af189490',
#  'p af189491',
#  'fips',
#  'admin2',
#  'province state',
#  'country region',
#  'last update',
#  'lat',
#  'long',
#  'confirmed',
#  'deaths',
#  'recovered',
#  'active',
#  'combined key',
#  'incidence rate',
#  'case fatality ratio',
#  'species name',
#  'taxonomy id',
#  'breed name',
#  'consent type',
#  'id case',
#  'id animal',
#  'animal age at collection',
#  'animal age unit',
#  'animal sex',
#  'animal neuter status',
#  'animal neuter date',
#  'entering method',
#  'animal main disease',
#  'animal sec disease',
#  'collection institution',
#  'collection department',
#  'collection service',
#  'collection person',
#  'collection time',
#  'collection year',
#  'specimen id',
#  'specimen type',
#  'primary container type',
#  'primary container volume',
#  'specimen volume',
#  'collection special conditions',
#  'patient fasting status',
#  'pre transport temp',
#  'transport sample type',
#  'transport person',
#  'transport mode',
#  'transport time',
#  'transport temp',
#  'reception person',
#  'reception time',
#  'specimen infectious',
#  'specimen infectious details',
#  'processing person',
#  'processing start time',
#  'processing specimen category',
#  'processing temp',
#  'sample id',
#  'sample type',
#  'sample size',
#  'sample size unit',
#  'storage container',
#  'fixation type',
#  'fixation start time',
#  'fixation stop time',
#  'sample quality methods',
#  'sample quality control',
#  'liquor number',
#  'storage time',
#  'storage temp',
#  'storage place',
#  'sample status',
#  'freeze thaw cycle',
#  'retrieval date',
#  'retrieval reason',
#  'project destination',
#  'shipping temp',
#  'species type',
#  'species name',
#  'species id',
#  'strain name',
#  'laboratory id',
#  'specimen lab id',
#  'specimen external id',
#  'biosafety level',
#  'depository institution',
#  'depository name',
#  'isolation date',
#  'isolation country',
#  'isolation region',
#  'isolation source',
#  'isolation source det',
#  'isolation source info',
#  'host species',
#  'host age at collection',
#  'host age unit',
#  'host sex',
#  'clinical significance',
#  'disease',
#  'disease detailed',
#  'consent',
#  'identifier',
#  'code name',
#  'coding system and version',
#  'events',
#  'unit',
#  'class',
#  'exact',
#  'encounter id',
#  'daytime',
#  'source location',
#  'current location',
#  'therapeutic area',
#  'type',
#  'type',
#  'consent id',
#  'status',
#  'daytime',
#  'status',
#  'daytime',
#  'gender',
#  'daytime',
#  'status',
#  'daytime',
#  'rate',
#  'daytime',
#  'body site',
#  'method',
#  'physiology state',
#  'regularity',
#  'symbolic pressure',
#  'diastolic pressure',
#  'mean pressure',
#  'daytime',
#  'body site',
#  'method',
#  'unit',
#  'drug',
#  'time pattern type',
#  'quantity',
#  'duration',
#  'administration event start time',
#  'administration event end time',
#  'administration route',
#  'gaelic',
#  'reason to stop drug',
#  'drug',
#  'time pattern type',
#  'quantity',
#  'frequency',
#  'first administration daytime',
#  'last administration daytime',
#  'administration route',
#  'gaelic',
#  'indication to start drug',
#  'culture medium rcid',
#  'temp conditions rcid',
#  'oxygen tolerance',
#  'mutations',
#  'was availability',
#  'genbank accession nb',
#  'other genotype information',
#  'storage format',
#  'storage temperature',
#  'derivative type',
#  'freeze thaw cycle',
#  'pmid',
#  'strain resistance antimicrobial',
#  'strain resistance class',
#  'strain resistance mic',
#  'strain resistance zd',
#  'strain resistance sir',
#  'used resistance guidelines',
#  'resistance phenotype',
#  'resistance genotype',
#  'method resistance',
#  'validated violence factors',
#  'stereotyping performed',
#  'stereotyping serogroup',
#  'dem location',
#  'dem pop total',
#  'dem pop under 18',
#  'dem pop under 5',
#  'dem an pop rth 18',
#  'dem an pop rth 30',
#  'dem an birth 18',
#  'dem tot feet',
#  'dem life birth 70',
#  'dem life birth 20',
#  'dem dep tot',
#  'dem dep child',
#  'dem dep old age',
#  'dem pop urban',
#  'dem an rth rate 18',
#  'dem an rth rate 30',
#  'dem net migration',
#  'location',
#  'under mor 90',
#  'under mor 00',
#  'under mor 18',
#  'under mor an',
#  'under mor male',
#  'under mor female',
#  'inf mor 90',
#  'inf mor 18',
#  'neo mor 90',
#  'neo mor 18',
#  'pro 90',
#  'pro 18',
#  'an death 90',
#  'an death 18',
#  'an neodeath 90',
#  'an neodeath 18',
#  'an neodeath under5 90',
#  'an neodeath under5 18',
#  'location',
#  'hiv inc 14',
#  'hiv inc 19',
#  'hiv inc 19 g',
#  'hiv inc 19 b',
#  'aids mor 14',
#  'aids mor 19',
#  'aids mor 19 g',
#  'aids mor 19 b',
#  'aids liv 14',
#  'aids liv 19',
#  'aids liv 19 g',
#  'aids liv 19 b',
#  'id patient',
#  'id patient local',
#  'id patient global',
#  'patient sex',
#  'id pathology',
#  'id case',
#  'consent type',
#  'consent answer',
#  'consent date',
#  'patient age at collection',
#  'patient age unit',
#  'patient prim disease',
#  'patient sec disease',
#  'collection institution',
#  'collection department',
#  'collection service',
#  'collection person',
#  'collection year',
#  'specimen id',
#  'camping time',
#  'collection time',
#  'collection procedure',
#  'specimen type',
#  'specimen morphological code',
#  'specimen topographical code',
#  'collection special conditions',
#  'collection special conditions text',
#  'patient fasting status',
#  'pre transport temp',
#  'transport sample type',
#  'transport person',
#  'transport mode',
#  'transport time',
#  'transport temp',
#  'reception person',
#  'reception time',
#  'specimen infectious',
#  'specimen infectious details',
#  'specimen infectious details text',
#  'processing person',
#  'processing start time',
#  'processing specimen category',
#  'processing temp',
#  'sample id',
#  'sample type',
#  'sample size',
#  'sample size unit',
#  'storage container',
#  'fixation type',
#  'fixation start time',
#  'fixation stop time',
#  'sample quality methods',
#  'sample quality control',
#  'liquor number',
#  'storage time',
#  'storage temp',
#  'storage place',
#  'sample status',
#  'freeze thaw cycle',
#  'retrieval date',
#  'retrieval reasons',
#  'retrieval reasons text',
#  'project destination',
#  'delivery temp',
#  'id patient',
#  'id patient local',
#  'id patient global',
#  'patient sex',
#  'collection institution',
#  'collection department',
#  'collection service',
#  'collection person',
#  'collection year',
#  'specimen id',
#  'specimen type',
#  'primary container type',
#  'primary container volume',
#  'specimen volume',
#  'collection special conditions',
#  'collection special conditions text',
#  'patient fasting status',
#  'pre transport temp',
#  'transport sample type',
#  'transport person',
#  'transport mode',
#  'transport time',
#  'transport temp',
#  'reception person',
#  'reception time',
#  'specimen infectious',
#  'specimen infectious details',
#  'specimen infectious details text',
#  'processing person',
#  'processing start time',
#  'processing temp',
#  'processing special conditions',
#  'processing special conditions text',
#  'prim centrifugal force',
#  'prim centrifugal temp',
#  'prim centrifugal duration',
#  'sec centrifugal force',
#  'sec centrifugal temp',
#  'sec centrifugal duration',
#  'sec centrifugal brake',
#  'postcentrifug temp',
#  'processing stop time',
#  'sample id',
#  'sample type',
#  'sample additive',
#  'sample additive text',
#  'sample volume',
#  'storage container',
#  'freezing mode',
#  'freezing time',
#  'freezing delay',
#  'liquor number',
#  'storage time',
#  'storage temp',
#  'storage place',
#  'sample status',
#  'freeze thaw cycle',
#  'retrieval date',
#  'retrieval reasons',
#  'retrieval reasons text',
#  'project destination',
#  'delivery temp',
#  'hth location',
#  'hth imm big',
#  'hth imm dp1',
#  'hth imm dp3',
#  'hth imm polio3',
#  'hth imm cv1',
#  'hth imm cv2',
#  'hth imm herb3',
#  'hth imm his3',
#  'hth imm nota',
#  'hth imm pc3',
#  'hth imm pab',
#  'hth pneumonia',
#  'hth dia ors',
#  'hth mal fever',
#  'hth mal you itn',
#  'hth mal itn',
#  'nut location',
#  'nut lower',
#  'nut weighed',
#  'feed early',
#  'feed exclusive',
#  'feed solids',
#  'feed children',
#  'feed poorest',
#  'feed richest',
#  'feed diet',
#  'feed meal',
#  'feed acceptable',
#  'feed zero',
#  'hiv location',
#  'hiv prev hiv',
#  'hiv earl hiv',
#  'hiv child 014',
#  'hiv child 1019',
#  'hiv comp male',
#  'hiv comp female',
#  'hiv cond male',
#  'hiv cond female',
#  'hiv idol male',
#  'hiv idol female',
#  'join ac id',
#  'attribute id',
#  'classification attribute id',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'join dac id',
#  'asset id',
#  'concept id',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'user ent id',
#  'user ent object',
#  'user ent object id',
#  'user id',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'join doc id',
#  'domain id',
#  'concept id',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'privacy level id',
#  'privacy lvl name',
#  'privacy lvl desc',
#  'privacy lvl display',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'sys deleted',
#  'reference id',
#  'reference category',
#  'reference value',
#  'reference code',
#  'reference desc',
#  'reference display',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'sys deleted',
#  'stakeholder id',
#  'stakeholder name',
#  'stakeholder contact info',
#  'stakeholder org unit',
#  'stakeholder note',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'sys deleted',
#  'discussion id',
#  'discussion object type',
#  'discussion object id',
#  'discussion user id',
#  'discussion text',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'trace setlist id',
#  'trace setlist object type',
#  'trace setlist object id',
#  'trace setlist status',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'property id',
#  'property name',
#  'property description',
#  'property type',
#  'property list',
#  'property default value',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'sys deleted',
#  'join prop id',
#  'object type id',
#  'object id',
#  'property id',
#  'join prop value',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'id',
#  'oldid',
#  'claimtype',
#  'claimvalue',
#  'id',
#  'name',
#  'normalizedname',
#  'concurrencystamp',
#  'id',
#  'userid',
#  'claimtype',
#  'claimvalue',
#  'loginprovider',
#  'providerkey',
#  'providerdisplayname',
#  'userid',
#  'attribute id',
#  'attribute technical name',
#  'attribute business name',
#  'attribute business desc',
#  'attribute business rule',
#  'attribute data type',
#  'attribute isp',
#  'attribute isnullable',
#  'attribute status id',
#  'asset id',
#  'sys batch id',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'sys deleted',
#  'sys lastscanned',
#  'sys ver validfrom',
#  'sys ver valid',
#  'userid',
#  'oldid',
#  'id',
#  'username',
#  'normalizedusername',
#  'firstname',
#  'lastname',
#  'email',
#  'normalizedemail',
#  'emailconfirmed',
#  'passwordhash',
#  'securitystamp',
#  'concurrencystamp',
#  'phonenumber',
#  'phonenumberconfirmed',
#  'twofactorenabled',
#  'lockoutend',
#  'lockoutenabled',
#  'accessfailedcount',
#  'userid',
#  'loginprovider',
#  'name',
#  'value',
#  'attribute id',
#  'attribute technical name',
#  'attribute business name',
#  'attribute business desc',
#  'attribute business rule',
#  'attribute data type',
#  'attribute isp',
#  'attribute isnullable',
#  'attribute status id',
#  'asset id',
#  'sys batch id',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'sys deleted',
#  'sys lastscanned',
#  'sys ver validfrom',
#  'sys ver valid',
#  'asset id',
#  'asset technical name',
#  'asset business name',
#  'asset business desc',
#  'asset status id',
#  'asset server name',
#  'asset database',
#  'asset schema',
#  'asset type id',
#  'asset sme id',
#  'application id',
#  'privacy level id',
#  'sys batch id',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'sys deleted',
#  'sys lastscanned',
#  'sys ver validfrom',
#  'sys ver valid',
#  'uscode',
#  'devicecode',
#  'subjected',
#  'client',
#  'creationtime',
#  'expiration',
#  'data',
#  'key',
#  'type',
#  'subjected',
#  'client',
#  'creationtime',
#  'expiration',
#  'data',
#  'asset id',
#  'asset technical name',
#  'asset business name',
#  'asset business desc',
#  'asset status id',
#  'asset server name',
#  'asset database',
#  'asset schema',
#  'asset type id',
#  'asset sme id',
#  'application id',
#  'privacy level id',
#  'sys batch id',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'sys deleted',
#  'sys lastscanned',
#  'sys ver validfrom',
#  'sys ver valid',
#  'application id',
#  'application name',
#  'application desc',
#  'application code',
#  'application status id',
#  'application sme id',
#  'business owner id',
#  'ict owner id',
#  'domain id',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'sys deleted',
#  'asset type id',
#  'asset type name',
#  'asset type desc',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'sys deleted',
#  'audit setlist id',
#  'audit setlist matchid',
#  'audit setlist config id',
#  'audit setlist server',
#  'audit setlist database',
#  'audit setlist schema',
#  'audit setlist notification',
#  'audit setlist status',
#  'audit setlist start date',
#  'audit setlist end date',
#  'sys lastmodified',
#  'audit classification id',
#  'audit classification config id',
#  'audit classification class id',
#  'audit classification domain id',
#  'audit classification application id',
#  'audit classification data asset id',
#  'audit classification notification',
#  'audit classification status',
#  'audit classification start date',
#  'audit classification end date',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'audit delete id',
#  'audit delete job',
#  'audit delete notification',
#  'audit delete status',
#  'audit delete start date',
#  'audit delete end date',
#  'sys lastmodified',
#  'audit hide id',
#  'audit hide notification',
#  'audit hide status',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'classification id',
#  'classification name',
#  'classification desc',
#  'classification code',
#  'classification sme id',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'sys deleted',
#  'classification attribute id',
#  'classification id',
#  'classification attribute name',
#  'classification attribute desc',
#  'classification attribute synonym',
#  'classification attribute exclusion',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'sys deleted',
#  'classification search id',
#  'classification id',
#  'classification attribute id',
#  'attribute id',
#  'config classification search id',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'concept id',
#  'concept name',
#  'concept desc',
#  'sys lastmodified',
#  'sys lastmodifiedby',
#  'sys deleted',
#  'config setlist id',
#  'config setlist server name',
#  'config setlist db name',
#  'config setlist db schema',
#  'config setlist application id',
#  'config setlist object type id',
#  ...]

# %% [markdown]
# <div style="background:#EEEDF5;color:#303030"><div style="margin-left: .2cm">
#     <b>Comments:</b>
# </div></div>
#
# <div style="margin-left: 0.4cm">
#     This Markdown cell is a template to write extended comments. e.g. explain the approach taken, or concepts behind algorithm chosen. Aim at having 2 lines at least. Anything smaller can be directly integrated in the code, or gathered together with other comments to form a bigger paragraph. Since this block is within a div element, you need to use html formatting syntax, not markdown
# </div>

# %% [markdown]
# <div style="background:#EEEDF5;border:0.1cm solid #FDB100;color:#303030">
#     <div style="margin: 0.2cm 0.2cm 0.2cm 0.2cm">
#         <b style="color:#FDB100">Title:</b>
#         This is a an example yellow box
#     </div>
# </div>

# %% [markdown]
# <div style="background:#EEEDF5;border:0.1cm solid #00BAE5;color:#303030">
#     <div style="margin: 0.2cm 0.2cm 0.2cm 0.2cm">
#         <b style="color:#00BAE5">Note:</b>
#         This is an example Blue Box
#     </div>
# </div>

# %% [markdown]
# <div style="background:#EEEDF5;border:0.1cm solid #EF475B;color:#303030">
#     <div style="margin: 0.2cm 0.2cm 0.2cm 0.2cm">
#         <b style="color:#EF475B">Warning:</b>
#         This is an example red box
#     </div>
# </div>

# %% [markdown]
# <a id='P2' name="P2"></a>
# ## [Part 2 title here](#P0)

# %% [markdown]
# <a id='P3' name="P3"></a>
# ## [Part 3 title here](#P0)

# %% [markdown]
# <a id='CL'></a>
# ## [Conclusion](#P0)
#
# This is a pre-written conclusion in which we have nice figures.

# %% [markdown]
# <div style="border-top:0.1cm solid #EF475B"></div>
#     <strong><a href='#Q0'><div style="text-align: right"> <h3>End of this Notebook.</h3></div></a></strong>
